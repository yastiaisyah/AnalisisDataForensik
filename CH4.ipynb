# %% [markdown]
# <a href="https://colab.research.google.com/github/yastiaisyah/Exploratory-Data-Analysis-with-Python-Cookbook/blob/main/CH4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Load dataset
url = 'https://raw.githubusercontent.com/PacktPublishing/Exploratory-Data-Analysis-with-Python-Cookbook/main/Ch4/Data/penguins_size.csv'
penguins_data = pd.read_csv(url)
#Subset for relevant columns
penguins_data = penguins_data[['species','culmen_length_mm']]
#Inspect first 5 rows and data types of the dataset
penguins_data.head()
# Out:
#   species  culmen_length_mm
# 0  Adelie              39.1
# 1  Adelie              39.5
# 2  Adelie              40.3
# 3  Adelie               NaN
# 4  Adelie              36.7

# %%
penguins_data.shape
# Out:
# (344, 2)

# %%
penguins_data.dtypes
# Out:
# species              object
# culmen_length_mm    float64
# dtype: object

# %%
#Create a histogram in Seaborn
sns.histplot( data = penguins_data, x= penguins_data["culmen_length_mm"])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Count'>

# %%
#Provide additional chart details
plt.figure(figsize= (12,6))

ax = sns.histplot( data = penguins_data, x= penguins_data["culmen_length_mm"])
ax.set_xlabel('Culmen Length in mm',fontsize = 15)
ax.set_ylabel('Count of records', fontsize = 15)
ax.set_title('Univariate analysis of Culmen Length', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Univariate analysis of Culmen Length')

# %%
#Create a bar plot using countplot method in Seaborn
sns.countplot(data = penguins_data, x= penguins_data['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#Provide additional chart details
plt.figure(figsize= (12,6))

ax = sns.countplot(data = penguins_data, x= penguins_data['species'])
ax.set_xlabel('Penguin Species',fontsize = 15)
ax.set_ylabel('Count of records',fontsize = 15)
ax.set_title('Univariate analysis of Penguin Species', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Univariate analysis of Penguin Species')

# %%
#Group our data to get count of species
penguins_group = penguins_data.groupby('species').count()
penguins_group
# Out:
#            culmen_length_mm
# species
# Adelie                  151
# Chinstrap                68
# Gentoo                  123

# %%
#Reset the index to ensure the index isn't the species column
penguins_group= penguins_group.reset_index()
penguins_group
# Out:
#      species  culmen_length_mm
# 0     Adelie               151
# 1  Chinstrap                68
# 2     Gentoo               123

# %%
#Create a pie chart in matplotlib
#create pie chart
plt.pie(penguins_group["culmen_length_mm"], labels = penguins_group['species'])
plt.show()

# %%
#Provide additional chart details
cols = ['g', 'b', 'r']

plt.pie(penguins_group["culmen_length_mm"], labels = penguins_group['species'],colors = cols)

plt.title('Univariate Analysis of Species', fontsize=15)
plt.show()

# %%
#Import relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Load dataset
url = 'https://raw.githubusercontent.com/PacktPublishing/Exploratory-Data-Analysis-with-Python-Cookbook/main/Ch3/Data/HousingPricesData.csv'
houseprices_data = pd.read_csv(url)
#Subset for relevant columns
houseprices_data = houseprices_data[['Zip','Price','Area','Room']]
#Inspect first 5 rows and data types of the dataset
houseprices_data.head()
# Out:
#        Zip     Price  Area  Room
# 0  1091 CR  685000.0    64     3
# 1  1059 EL  475000.0    60     3
# 2  1097 SM  850000.0   109     4
# 3  1060 TH  580000.0   128     6
# 4  1036 KN  720000.0   138     5

# %%
houseprices_data.shape
# Out:
# (924, 4)

# %%
houseprices_data.dtypes
# Out:
# Zip       object
# Price    float64
# Area       int64
# Room       int64
# dtype: object

# %%
#Create a Boxplot in Seaborn
sns.boxplot(data = houseprices_data, x= houseprices_data["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
#Provide additional chart details
plt.figure(figsize= (12,6))

ax = sns.boxplot(data = houseprices_data, x= houseprices_data["Price"])
ax.set_xlabel('House Prices in millions',fontsize = 15)
ax.set_title('Univariate analysis of House Prices', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')

# %%
#Create a Violinplot in Seaborn
sns.violinplot(data = houseprices_data, x= houseprices_data["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
#Provide additional chart details
plt.figure(figsize= (12,6))

ax = sns.violinplot(data = houseprices_data, x= houseprices_data["Price"])
ax.set_xlabel('House Prices in millions',fontsize = 15)
ax.set_title('Univariate analysis of House Prices', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')

# %%
#Create a Summary Table using the describe method in Pandas
houseprices_data.describe()
# Out:
#               Price        Area        Room
# count  9.200000e+02  924.000000  924.000000
# mean   6.220654e+05   95.952381    3.571429
# std    5.389942e+05   57.447436    1.592332
# min    1.750000e+05   21.000000    1.000000
# 25%    3.500000e+05   60.750000    3.000000
# 50%    4.670000e+05   83.000000    3.000000
# 75%    7.000000e+05  113.000000    4.000000
# max    5.950000e+06  623.000000   14.000000
