# %% [markdown]
# <a href="https://colab.research.google.com/github/yastiaisyah/Exploratory-Data-Analysis-with-Python-Cookbook/blob/main/CH1_1%262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import relevant libraries
import numpy as np
import pandas as pd
from scipy import stats
#Load data into dataframe
url = 'https://raw.githubusercontent.com/PacktPublishing/Exploratory-Data-Analysis-with-Python-Cookbook/main/Ch1/Data/covid-data.csv'
covid_data = pd.read_csv(url)
#Inspect the dataframe
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
covid_data = covid_data[['iso_code','continent','location','date','total_cases','new_cases']]
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0

# %%
covid_data.dtypes
# Out:
# iso_code       object
# continent      object
# location       object
# date           object
# total_cases     int64
# new_cases       int64
# dtype: object

# %%
covid_data.shape
# Out:
# (5818, 6)

# %%
#Analyse the mean of the new_cases column using the mean method in numpy
data_mean = np.mean(covid_data["new_cases"])
data_mean
# Out:
# 8814.365761430045

# %%
#Analyse the mean of the new_cases column using the mean method in pandas
data_mean = covid_data["new_cases"].mean()
data_mean
# Out:
# 8814.365761430045

# %%
#Check the median of the new_cases column using the median method in numpy
data_median = np.median(covid_data["new_cases"])
data_median
# Out:
# 261.0

# %%
#Check the median of the new_cases column using the median method in pandas
data_median = covid_data["new_cases"].median()
data_median
# Out:
# 261.0
